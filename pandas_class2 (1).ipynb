# %%
import pandas as pd

# %%
df = pd.read_csv("D:/pandas/weather_data.csv")
df
# Out:
#           day  temprature  windspeed   event
# 0  01-01-2021        32.0        6.0   Rainy
# 1  02-01-2021         NaN        9.0   Sunny
# 2  03-01-2021        28.0        NaN    Snow
# 3  04-01-2021         NaN        7.0     NaN
# 4  05-01-2021        32.0        NaN   Rainy
# 5  06-01-2021         NaN        NaN   Sunny
# 6  07-01-2021         NaN        NaN     NaN
# 7  08-01-2021        34.0        8.0     NaN
# 8  09-01-2021        40.0       12.0  Cloudy
# 9  10-01-2021        37.0       10.0   Sunny

# %%
type('day')
# Out:
# str

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.read_csv('D:/pandas/weather_data.csv', parse_dates = ['day'])
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
type('day')
# Out:
# str

# %%
# the first way to handel the missing values is to fill some other values at the place of NaN. 

# for doing that we will use fillna(what_we_want_to_fill)
newdf = df.fillna(0)
newdf
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         0.0        9.0   Sunny
# 2 2021-03-01        28.0        0.0    Snow
# 3 2021-04-01         0.0        7.0       0
# 4 2021-05-01        32.0        0.0   Rainy
# 5 2021-06-01         0.0        0.0   Sunny
# 6 2021-07-01         0.0        0.0       0
# 7 2021-08-01        34.0        8.0       0
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
newdf2 = df.fillna({'temprature':0,'windspeed':0,'event':'no events'})
newdf2
# Out:
#          day  temprature  windspeed      event
# 0 2021-01-01        32.0        6.0      Rainy
# 1 2021-02-01         0.0        9.0      Sunny
# 2 2021-03-01        28.0        0.0       Snow
# 3 2021-04-01         0.0        7.0  no events
# 4 2021-05-01        32.0        0.0      Rainy
# 5 2021-06-01         0.0        0.0      Sunny
# 6 2021-07-01         0.0        0.0  no events
# 7 2021-08-01        34.0        8.0  no events
# 8 2021-09-01        40.0       12.0     Cloudy
# 9 2021-10-01        37.0       10.0      Sunny

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
new3 = df.fillna(method="ffill")
new3
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01        32.0        9.0   Sunny
# 2 2021-03-01        28.0        9.0    Snow
# 3 2021-04-01        28.0        7.0    Snow
# 4 2021-05-01        32.0        7.0   Rainy
# 5 2021-06-01        32.0        7.0   Sunny
# 6 2021-07-01        32.0        7.0   Sunny
# 7 2021-08-01        34.0        8.0   Sunny
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
new3 = df.fillna(method="bfill")
new3
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01        28.0        9.0   Sunny
# 2 2021-03-01        28.0        7.0    Snow
# 3 2021-04-01        32.0        7.0   Rainy
# 4 2021-05-01        32.0        8.0   Rainy
# 5 2021-06-01        34.0        8.0   Sunny
# 6 2021-07-01        34.0        8.0  Cloudy
# 7 2021-08-01        34.0        8.0  Cloudy
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
xdf = df.interpolate()
xdf
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01   32.000000       6.00   Rainy
# 1 2021-02-01   30.000000       9.00   Sunny
# 2 2021-03-01   28.000000       8.00    Snow
# 3 2021-04-01   30.000000       7.00     NaN
# 4 2021-05-01   32.000000       7.25   Rainy
# 5 2021-06-01   32.666667       7.50   Sunny
# 6 2021-07-01   33.333333       7.75     NaN
# 7 2021-08-01   34.000000       8.00     NaN
# 8 2021-09-01   40.000000      12.00  Cloudy
# 9 2021-10-01   37.000000      10.00   Sunny

# %%
df26 = new3.interpolate()
df26
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01        28.0        9.0   Sunny
# 2 2021-03-01        28.0        7.0    Snow
# 3 2021-04-01        32.0        7.0   Rainy
# 4 2021-05-01        32.0        8.0   Rainy
# 5 2021-06-01        34.0        8.0   Sunny
# 6 2021-07-01        34.0        8.0  Cloudy
# 7 2021-08-01        34.0        8.0  Cloudy
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
newdf4 = df.T
newdf4
# Out:
#                               0                    1                    2  \
# day         2021-01-01 00:00:00  2021-02-01 00:00:00  2021-03-01 00:00:00
# temprature                   32                  NaN                   28
# windspeed                     6                    9                  NaN
# event                     Rainy                Sunny                 Snow
#
#                               3                    4                    5  \
# day         2021-04-01 00:00:00  2021-05-01 00:00:00  2021-06-01 00:00:00
# temprature                  NaN                   32                  NaN
# windspeed                     7                  NaN                  NaN
# event                       NaN                Rainy                Sunny
#
#                     6                    7                    8  \
# day        2021-07-01  2021-08-01 00:00:00  2021-09-01 00:00:00
# temprature        NaT                   34                   40
# ...

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
newdf5 = newdf4.fillna(method="ffill",axis="columns")
newdf5
# Out:
#                               0                    1                    2  \
# day         2021-01-01 00:00:00  2021-02-01 00:00:00  2021-03-01 00:00:00
# temprature                   32                   32                   28
# windspeed                     6                    9                    9
# event                     Rainy                Sunny                 Snow
#
#                               3                    4                    5  \
# day         2021-04-01 00:00:00  2021-05-01 00:00:00  2021-06-01 00:00:00
# temprature                   28                   32                   32
# windspeed                     7                    7                    7
# event                      Snow                Rainy                Sunny
#
#                               6                    7                    8  \
# day         2021-07-01 00:00:00  2021-08-01 00:00:00  2021-09-01 00:00:00
# ...

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
newdf6 = df.fillna(method="ffill", limit=1)
newdf6
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01        32.0        9.0   Sunny
# 2 2021-03-01        28.0        9.0    Snow
# 3 2021-04-01        28.0        7.0    Snow
# 4 2021-05-01        32.0        7.0   Rainy
# 5 2021-06-01        32.0        NaN   Sunny
# 6 2021-07-01         NaN        NaN   Sunny
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
newdf7 = df.interpolate()
newdf7
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01   32.000000       6.00   Rainy
# 1 2021-02-01   30.000000       9.00   Sunny
# 2 2021-03-01   28.000000       8.00    Snow
# 3 2021-04-01   30.000000       7.00     NaN
# 4 2021-05-01   32.000000       7.25   Rainy
# 5 2021-06-01   32.666667       7.50   Sunny
# 6 2021-07-01   33.333333       7.75     NaN
# 7 2021-08-01   34.000000       8.00     NaN
# 8 2021-09-01   40.000000      12.00  Cloudy
# 9 2021-10-01   37.000000      10.00   Sunny

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
df21 = df.dropna()
df21
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
df22 = df.dropna(how='all')
df22
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        32.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
df.loc[4,'temprature']=40

# %%
df
# Out:
#          day  temprature  windspeed   event
# 0 2021-01-01        32.0        6.0   Rainy
# 1 2021-02-01         NaN        9.0   Sunny
# 2 2021-03-01        28.0        NaN    Snow
# 3 2021-04-01         NaN        7.0     NaN
# 4 2021-05-01        40.0        NaN   Rainy
# 5 2021-06-01         NaN        NaN   Sunny
# 6 2021-07-01         NaN        NaN     NaN
# 7 2021-08-01        34.0        8.0     NaN
# 8 2021-09-01        40.0       12.0  Cloudy
# 9 2021-10-01        37.0       10.0   Sunny

# %%
df23 = df.set_index('day')
df23
# Out:
#             temprature  windspeed   event
# day
# 2021-01-01        32.0        6.0   Rainy
# 2021-02-01         NaN        9.0   Sunny
# 2021-03-01        28.0        NaN    Snow
# 2021-04-01         NaN        7.0     NaN
# 2021-05-01        32.0        NaN   Rainy
# 2021-06-01         NaN        NaN   Sunny
# 2021-07-01         NaN        NaN     NaN
# 2021-08-01        34.0        8.0     NaN
# 2021-09-01        40.0       12.0  Cloudy
# 2021-10-01        37.0       10.0   Sunny

# %%
df24 = df23.dropna(how='all')
df24
# Out:
#             temprature  windspeed   event
# day
# 2021-01-01        32.0        6.0   Rainy
# 2021-02-01         NaN        9.0   Sunny
# 2021-03-01        28.0        NaN    Snow
# 2021-04-01         NaN        7.0     NaN
# 2021-05-01        32.0        NaN   Rainy
# 2021-06-01         NaN        NaN   Sunny
# 2021-08-01        34.0        8.0     NaN
# 2021-09-01        40.0       12.0  Cloudy
# 2021-10-01        37.0       10.0   Sunny

# %%
df25 = df23.dropna(thresh=2)
df25
# Out:
#             temprature  windspeed   event
# day
# 2021-01-01        32.0        6.0   Rainy
# 2021-02-01         NaN        9.0   Sunny
# 2021-03-01        28.0        NaN    Snow
# 2021-05-01        32.0        NaN   Rainy
# 2021-08-01        34.0        8.0     NaN
# 2021-09-01        40.0       12.0  Cloudy
# 2021-10-01        37.0       10.0   Sunny

# %%
df23
# Out:
#             temprature  windspeed   event
# day
# 2021-01-01        32.0        6.0   Rainy
# 2021-02-01         NaN        9.0   Sunny
# 2021-03-01        28.0        NaN    Snow
# 2021-04-01         NaN        7.0     NaN
# 2021-05-01        32.0        NaN   Rainy
# 2021-06-01         NaN        NaN   Sunny
# 2021-07-01         NaN        NaN     NaN
# 2021-08-01        34.0        8.0     NaN
# 2021-09-01        40.0       12.0  Cloudy
# 2021-10-01        37.0       10.0   Sunny

# %%
df27 = df23.reset_index(drop=True)
df27
# Out:
#    temprature  windspeed   event
# 0        32.0        6.0   Rainy
# 1         NaN        9.0   Sunny
# 2        28.0        NaN    Snow
# 3         NaN        7.0     NaN
# 4        32.0        NaN   Rainy
# 5         NaN        NaN   Sunny
# 6         NaN        NaN     NaN
# 7        34.0        8.0     NaN
# 8        40.0       12.0  Cloudy
# 9        37.0       10.0   Sunny

# %%
mdf = pd.read_csv('D:/pandas/weather_data2.csv')
mdf
# Out:
#           day temprature windspeed   event
# 0  01-01-2021        32F         6   Rainy
# 1  02-01-2021     -99999     9 mph   Sunny
# 2  03-01-2021         28    -99999    Snow
# 3  04-01-2021     -99999         7       0
# 4  05-01-2021         32    -99999   Rainy
# 5  08-01-2021        34C         8       0
# 6  09-01-2021         40      7mph  Cloudy
# 7  10-01-2021       37 f    10 mph   Sunny

# %%
import numpy as np

# %%
mdf1 = mdf.replace('-99999',np.NaN)

# %%
mdf1
# Out:
#           day temprature windspeed   event
# 0  01-01-2021        32F         6   Rainy
# 1  02-01-2021        NaN     9 mph   Sunny
# 2  03-01-2021         28       NaN    Snow
# 3  04-01-2021        NaN         7       0
# 4  05-01-2021         32       NaN   Rainy
# 5  08-01-2021        34C         8       0
# 6  09-01-2021         40      7mph  Cloudy
# 7  10-01-2021       37 f    10 mph   Sunny

# %%
mdf
# Out:
#           day temprature windspeed   event
# 0  01-01-2021        32F         6   Rainy
# 1  02-01-2021     -99999     9 mph   Sunny
# 2  03-01-2021         28    -99999    Snow
# 3  04-01-2021     -99999         7       0
# 4  05-01-2021         32    -99999   Rainy
# 5  08-01-2021        34C         8       0
# 6  09-01-2021         40      7mph  Cloudy
# 7  10-01-2021       37 f    10 mph   Sunny

# %%
mdf[mdf<'0']='0'

# %%
mdf
# Out:
#           day temprature windspeed   event
# 0  01-01-2021        32F         6   Rainy
# 1  02-01-2021          0     9 mph   Sunny
# 2  03-01-2021         28         0    Snow
# 3  04-01-2021          0         7       0
# 4  05-01-2021         32         0   Rainy
# 5  08-01-2021        34C         8       0
# 6  09-01-2021         40      7mph  Cloudy
# 7  10-01-2021       37 f    10 mph   Sunny
